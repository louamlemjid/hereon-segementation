# %%
import mlflow.pyfunc

model = mlflow.pyfunc.load_model(
    "models:/custom_unet/Production"
)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 3
#       1 import mlflow.pyfunc
# ----> 3 model = mlflow.pyfunc.load_model(
#       4     "models:/custom_unet/Production"
#       5 )
#
# File ~/.local/lib/python3.10/site-packages/mlflow/tracing/provider.py:861, in trace_disabled.<locals>.wrapper(*args, **kwargs)
#     859 try:
#     860     is_func_called = True
# --> 861     result = f(*args, **kwargs)
#     862 finally:
#     863     enable()
#
# File ~/.local/lib/python3.10/site-packages/mlflow/pyfunc/__init__.py:1128, in load_model(model_uri, suppress_warnings, dst_path, model_config)
#    1124         entity_list.append(Entity(job=job_entity))
#    1126     lineage_header_info = LineageHeaderInfo(entities=entity_list) if entity_list else None
# -> 1128 local_path = _download_artifact_from_uri(
#    1129     artifact_uri=model_uri, output_path=dst_path, lineage_header_info=lineage_header_info
#    1130 )
#    1132 if not suppress_warnings:
#    1133     model_requirements = _get_pip_requirements_from_model_path(local_path)
#
# File ~/.local/lib/python3.10/site-packages/mlflow/tracking/artifact_utils.py:123, in _download_artifact_from_uri(artifact_uri, output_path, lineage_header_info, tracking_uri, registry_uri)
#     121 try:
#     122     if isinstance(repo, ModelsArtifactRepository):
# --> 123         return repo.download_artifacts(
#     124             artifact_path=artifact_path,
#     125             dst_path=output_path,
#     126             lineage_header_info=lineage_header_info,
#     127         )
#     128     return repo.download_artifacts(artifact_path=artifact_path, dst_path=output_path)
#     129 except Exception as e:
#
# File ~/.local/lib/python3.10/site-packages/mlflow/store/artifact/models_artifact_repo.py:249, in ModelsArtifactRepository.download_artifacts(self, artifact_path, dst_path, lineage_header_info)
#     245     model_path = self.repo.download_artifacts(
#     246         artifact_path, dst_path, lineage_header_info=lineage_header_info
#     247     )
#     248 else:
# --> 249     model_path = self.repo.download_artifacts(artifact_path, dst_path)
#     250 # NB: only add the registered model metadata iff the artifact path is at the root model
#     251 # directory. For individual files or subdirectories within the model directory, do not
#     252 # create the metadata file.
#     253 if os.path.isdir(model_path) and MLMODEL_FILE_NAME in os.listdir(model_path):
#
# File ~/.local/lib/python3.10/site-packages/mlflow/store/artifact/local_artifact_repo.py:93, in LocalArtifactRepository.download_artifacts(self, artifact_path, dst_path)
#      91 validate_path_within_directory(self.artifact_dir, local_artifact_path)
#      92 if not os.path.exists(local_artifact_path):
# ---> 93     raise OSError(f"No such file or directory: '{local_artifact_path}'")
#      94 return os.path.abspath(local_artifact_path)
#
# OSError: No such file or directory: '/teamspace/studios/this_studio/hereon_segementation/mlops/mlruns/1/models/m-2b225711b730482d95da220ce0c41b03/artifacts/.'

# %%
import sqlite3

conn = sqlite3.connect("/home/hm/Bureau/Hereon/docker-work/segmentation/mlops/mlflow.db")
cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

for table in tables:
    print(table[0])

# %%
from mlflow.tracking import MlflowClient

client = MlflowClient()

exp =  client.search_experiments()[0]

print(exp)
# Out:
# <Experiment: artifact_location='/teamspace/studios/this_studio/hereon_segementation/mlops/mlruns/1', creation_time=1775659131548, experiment_id='1', last_update_time=1775659131548, lifecycle_stage='active', name='segmentation_unet', tags={}, trace_location=None, workspace='default'>

# %%
from mlflow.tracking import MlflowClient

client = MlflowClient()

for rm in client.search_registered_models():
    for mv in rm.latest_versions:
        if mv.current_stage == "Production":
            print(f"Model: {rm.name}, Version: {mv.version}")
# Out:
# Model: custom_unet, Version: 2
